# %%
# ─── 1. IMPORT LIBRARIES & SETUP ───────────────────────────────────────────
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    roc_auc_score
)

DATA_DIR = r"C:\Users\Admin\Downloads\Compressed\FaceForensics++\data_flat"  # adjust as needed
SEED = 42

# ─── 2. LOAD PRETRAINED BASE MODELS ────────────────────────────────────────
model_x = load_model("xception_deepfake.h5")
model_v = load_model("vgg19.h5")
model_e = load_model("efficientnetb0.h5")
model_r = load_model("resnet50.h5")
model_m = load_model("mobilenetv2.h5")

# ─── 3. PREPARE VALIDATION DATA GENERATORS ────────────────────────────────
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
gen_224 = datagen.flow_from_directory(
    DATA_DIR, target_size=(224,224),
    batch_size=32, class_mode="binary",
    subset="validation", shuffle=False
)
gen_299 = datagen.flow_from_directory(
    DATA_DIR, target_size=(299,299),
    batch_size=32, class_mode="binary",
    subset="validation", shuffle=False
)
y_true = gen_224.classes  # same order for both gens

# ─── 4. GENERATE BASE‑MODEL PREDICTIONS ────────────────────────────────────
pred_x = model_x.predict(gen_299, verbose=1)
pred_v = model_v.predict(gen_224, verbose=1)
pred_e = model_e.predict(gen_224, verbose=1)
pred_r = model_r.predict(gen_224, verbose=1)
pred_m = model_m.predict(gen_224, verbose=1)

# Stack into (n_samples × 5) meta‑feature matrix
X_meta = np.hstack([pred_x, pred_v, pred_e, pred_r, pred_m])

# ─── 5. HOLD‑OUT SPLIT FOR GENERALIZATION TEST ─────────────────────────────
X_train, X_test, y_train, y_test = train_test_split(
    X_meta, y_true, test_size=0.3,
    stratify=y_true, random_state=SEED
)

# ─── 6. SCALE META‑FEATURES ────────────────────────────────────────────────
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# ─── 7. RANDOM FOREST META‑MODEL ──────────────────────────────────────────
rf = RandomForestClassifier(
    n_estimators=200,
    class_weight="balanced",
    random_state=SEED
)
rf.fit(X_train_scaled, y_train)
y_pred_rf = rf.predict(X_test_scaled)
print("🔹 RF Accuracy:", accuracy_score(y_test, y_pred_rf))

# ─── 8. LOGISTIC REGRESSION META‑MODEL ────────────────────────────────────
lr = LogisticRegression(
    class_weight="balanced",
    max_iter=1000,
    random_state=SEED
)
lr.fit(X_train_scaled, y_train)
y_pred_lr = lr.predict(X_test_scaled)
print("🔹 LR Accuracy:", accuracy_score(y_test, y_pred_lr))

# ─── 9. XGBOOST META‑MODEL ────────────────────────────────────────────────
xgb = XGBClassifier(
    n_estimators=300,
    learning_rate=0.1,
    max_depth=5,
    use_label_encoder=False,
    eval_metric="logloss",
    random_state=SEED
)
xgb.fit(X_train_scaled, y_train)
y_pred_xgb  = xgb.predict(X_test_scaled)
y_prob_xgb  = xgb.predict_proba(X_test_scaled)[:,1]
print("🔹 XGB Accuracy:", accuracy_score(y_test, y_pred_xgb))
print("🔹 XGB ROC AUC:", roc_auc_score(y_test, y_prob_xgb))

# ─── 10. STRATIFIED K‑FOLD CV WITH RANDOM FOREST ──────────────────────────
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
cv_accuracies = []

for fold, (tr_idx, va_idx) in enumerate(skf.split(X_meta, y_true), 1):
    X_tr, X_va = X_meta[tr_idx], X_meta[va_idx]
    y_tr, y_va = y_true[tr_idx], y_true[va_idx]
    sc = StandardScaler().fit(X_tr)
    X_tr_s, X_va_s = sc.transform(X_tr), sc.transform(X_va)
    rf_cv = RandomForestClassifier(
        n_estimators=300,
        max_depth=10,
        class_weight="balanced",
        random_state=SEED
    ).fit(X_tr_s, y_tr)
    acc = accuracy_score(y_va, rf_cv.predict(X_va_s))
    cv_accuracies.append(acc)
print("🔹 5‑Fold RF CV Accuracies:", cv_accuracies)
print("🔹 Mean CV Accuracy:", np.mean(cv_accuracies))

# ─── 11. NEURAL‑NET META‑MODEL (ADAM OPTIMIZER) ────────────────────────────
model_meta = Sequential([
    Dense(64, activation="relu", input_shape=(5,)),
    Dense(32, activation="relu"),
    Dense(1, activation="sigmoid")
])
model_meta.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)
history = model_meta.fit(
    X_train_scaled, y_train,
    validation_data=(X_test_scaled, y_test),
    epochs=25, batch_size=32, verbose=2
)
y_pred_nn = (model_meta.predict(X_test_scaled) > 0.5).astype(int).ravel()
print("🔹 NN Meta Accuracy:", accuracy_score(y_test, y_pred_nn))

# ─── 12. FINAL EVALUATION REPORT ──────────────────────────────────────────
for name, preds in [
    ("RF",   y_pred_rf),
    ("LR",   y_pred_lr),
    ("XGB",  y_pred_xgb),
    ("NN",   y_pred_nn)
]:
    print(f"\n=== {name} Classification Report ===")
    print(classification_report(y_test, preds, target_names=["Fake","Real"]))
    print("Confusion Matrix:\n", confusion_matrix(y_test, preds))
# Out:
# Found 2112 images belonging to 2 classes.
# Found 2112 images belonging to 2 classes.
# 66/66 [==============================] - 157s 2s/step
# 66/66 [==============================] - 126s 2s/step
# 66/66 [==============================] - 41s 598ms/step
# 66/66 [==============================] - 63s 939ms/step
# 66/66 [==============================] - 31s 462ms/step
# 🔹 RF Accuracy: 0.6545741324921136
# 🔹 LR Accuracy: 0.5757097791798107
# C:\Users\Admin\anaconda3\envs\deepfake_detection\lib\site-packages\xgboost\core.py:158: UserWarning: [16:09:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 🔹 XGB Accuracy: 0.6498422712933754
# 🔹 XGB ROC AUC: 0.718223736968725
# 🔹 5‑Fold RF CV Accuracies: [0.6950354609929078, 0.6359338061465721, 0.6966824644549763, 0.6469194312796208, 0.6800947867298578]
# 🔹 Mean CV Accuracy: 0.670933189920787
# Epoch 1/25
# 47/47 - 1s - loss: 0.6763 - accuracy: 0.5812 - val_loss: 0.6577 - val_accuracy: 0.6167 - 738ms/epoch - 16ms/step
# Epoch 2/25
# 47/47 - 0s - loss: 0.6551 - accuracy: 0.6231 - val_loss: 0.6484 - val_accuracy: 0.6309 - 47ms/epoch - 1ms/step
# Epoch 3/25
# 47/47 - 0s - loss: 0.6472 - accuracy: 0.6319 - val_loss: 0.6485 - val_accuracy: 0.6325 - 79ms/epoch - 2ms/step
# Epoch 4/25
# 47/47 - 0s - loss: 0.6423 - accuracy: 0.6340 - val_loss: 0.6405 - val_accuracy: 0.6656 - 79ms/epoch - 2ms/step
# Epoch 5/25
# 47/47 - 0s - loss: 0.6378 - accuracy: 0.6407 - val_loss: 0.6410 - val_accuracy: 0.6483 - 80ms/epoch - 2ms/step
# Epoch 6/25
# 47/47 - 0s - loss: 0.6339 - accuracy: 0.6461 - val_loss: 0.6354 - val_accuracy: 0.6577 - 79ms/epoch - 2ms/step
# Epoch 7/25
# 47/47 - 0s - loss: 0.6301 - accuracy: 0.6543 - val_loss: 0.6356 - val_accuracy: 0.6451 - 63ms/epoch - 1ms/step
# Epoch 8/25
# 47/47 - 0s - loss: 0.6269 - accuracy: 0.6556 - val_loss: 0.6315 - val_accuracy: 0.6514 - 95ms/epoch - 2ms/step
# Epoch 9/25
# 47/47 - 0s - loss: 0.6237 - accuracy: 0.6549 - val_loss: 0.6323 - val_accuracy: 0.6546 - 63ms/epoch - 1ms/step
# Epoch 10/25
# 47/47 - 0s - loss: 0.6214 - accuracy: 0.6617 - val_loss: 0.6333 - val_accuracy: 0.6498 - 64ms/epoch - 1ms/step
# Epoch 11/25
# 47/47 - 0s - loss: 0.6208 - accuracy: 0.6543 - val_loss: 0.6299 - val_accuracy: 0.6672 - 64ms/epoch - 1ms/step
# Epoch 12/25
# 47/47 - 0s - loss: 0.6167 - accuracy: 0.6631 - val_loss: 0.6290 - val_accuracy: 0.6577 - 63ms/epoch - 1ms/step
# Epoch 13/25
# 47/47 - 0s - loss: 0.6132 - accuracy: 0.6678 - val_loss: 0.6300 - val_accuracy: 0.6640 - 95ms/epoch - 2ms/step
# Epoch 14/25
# 47/47 - 0s - loss: 0.6137 - accuracy: 0.6651 - val_loss: 0.6236 - val_accuracy: 0.6688 - 79ms/epoch - 2ms/step
# Epoch 15/25
# 47/47 - 0s - loss: 0.6107 - accuracy: 0.6590 - val_loss: 0.6227 - val_accuracy: 0.6483 - 79ms/epoch - 2ms/step
# Epoch 16/25
# 47/47 - 0s - loss: 0.6095 - accuracy: 0.6509 - val_loss: 0.6214 - val_accuracy: 0.6782 - 63ms/epoch - 1ms/step
# Epoch 17/25
# 47/47 - 0s - loss: 0.6066 - accuracy: 0.6590 - val_loss: 0.6179 - val_accuracy: 0.6656 - 80ms/epoch - 2ms/step
# Epoch 18/25
# 47/47 - 0s - loss: 0.6075 - accuracy: 0.6644 - val_loss: 0.6191 - val_accuracy: 0.6735 - 63ms/epoch - 1ms/step
# Epoch 19/25
# 47/47 - 0s - loss: 0.6034 - accuracy: 0.6732 - val_loss: 0.6239 - val_accuracy: 0.6483 - 79ms/epoch - 2ms/step
# Epoch 20/25
# 47/47 - 0s - loss: 0.6009 - accuracy: 0.6732 - val_loss: 0.6139 - val_accuracy: 0.6751 - 79ms/epoch - 2ms/step
# Epoch 21/25
# 47/47 - 0s - loss: 0.5996 - accuracy: 0.6712 - val_loss: 0.6170 - val_accuracy: 0.6656 - 95ms/epoch - 2ms/step
# Epoch 22/25
# 47/47 - 0s - loss: 0.5958 - accuracy: 0.6752 - val_loss: 0.6181 - val_accuracy: 0.6609 - 95ms/epoch - 2ms/step
# Epoch 23/25
# 47/47 - 0s - loss: 0.5935 - accuracy: 0.6651 - val_loss: 0.6143 - val_accuracy: 0.6656 - 95ms/epoch - 2ms/step
# Epoch 24/25
# 47/47 - 0s - loss: 0.5910 - accuracy: 0.6725 - val_loss: 0.6118 - val_accuracy: 0.6672 - 79ms/epoch - 2ms/step
# Epoch 25/25
# 47/47 - 0s - loss: 0.5893 - accuracy: 0.6712 - val_loss: 0.6118 - val_accuracy: 0.6640 - 95ms/epoch - 2ms/step
# 20/20 [==============================] - 0s 830us/step
# 🔹 NN Meta Accuracy: 0.6640378548895899
#
# === RF Classification Report ===
#               precision    recall  f1-score   support
#
#         Fake       0.62      0.64      0.63       290
#         Real       0.69      0.66      0.68       344
#
#     accuracy                           0.65       634
#    macro avg       0.65      0.65      0.65       634
# weighted avg       0.66      0.65      0.66       634
#
# Confusion Matrix:
#  [[187 103]
#  [116 228]]
#
# === LR Classification Report ===
#               precision    recall  f1-score   support
#
#         Fake       0.54      0.50      0.52       290
#         Real       0.60      0.64      0.62       344
#
#     accuracy                           0.58       634
#    macro avg       0.57      0.57      0.57       634
# weighted avg       0.57      0.58      0.57       634
#
# Confusion Matrix:
#  [[146 144]
#  [125 219]]
#
# === XGB Classification Report ===
#               precision    recall  f1-score   support
#
#         Fake       0.61      0.63      0.62       290
#         Real       0.68      0.67      0.67       344
#
#     accuracy                           0.65       634
#    macro avg       0.65      0.65      0.65       634
# weighted avg       0.65      0.65      0.65       634
#
# Confusion Matrix:
#  [[182 108]
#  [114 230]]
#
# === NN Classification Report ===
#               precision    recall  f1-score   support
#
#         Fake       0.63      0.65      0.64       290
#         Real       0.70      0.68      0.69       344
#
#     accuracy                           0.66       634
#    macro avg       0.66      0.66      0.66       634
# weighted avg       0.66      0.66      0.66       634
#
# Confusion Matrix:
#  [[188 102]
#  [111 233]]
